# %% [markdown]
# # Higher Education Consulting Analysis

# %% [markdown]
# ## Library Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Import and Overview

# %%
df = pd.read_csv('data/universities.csv')
# imports the csv file as a dataframe

# %%
df.head()
# outputs the first 5 rows of data
# Out:
#                         College Name State  Public (1)/ Private (2)  \
# 0          Alaska Pacific University    AK                        2
# 1  University of Alaska at Fairbanks    AK                        1
# 2     University of Alaska Southeast    AK                        1
# 3  University of Alaska at Anchorage    AK                        1
# 4        Alabama Agri. & Mech. Univ.    AL                        1
#
#    # appli. rec'd  # appl. accepted  # new stud. enrolled  \
# 0           193.0             146.0                  55.0
# 1          1852.0            1427.0                 928.0
# 2           146.0             117.0                  89.0
# 3          2065.0            1598.0                1162.0
# 4          2817.0            1920.0                 984.0
#
#    % new stud. from top 10%  % new stud. from top 25%  # FT undergrad  \
# 0                      16.0                      44.0           249.0
# 1                       NaN                       NaN          3885.0
# 2                       4.0                      24.0           492.0
# 3                       NaN                       NaN          6209.0
# 4                       NaN                       NaN          3958.0
#
#    # PT undergrad  in-state tuition  out-of-state tuition    room   board  \
# 0           869.0            7560.0                7560.0  1620.0  2500.0
# 1          4519.0            1742.0                5226.0  1800.0  1790.0
# 2          1849.0            1742.0                5226.0  2514.0  2250.0
# 3         10537.0            1742.0                5226.0  2600.0  2520.0
# 4           305.0            1700.0                3400.0  1108.0  1442.0
#
#    add. fees  estim. book costs  estim. personal $  % fac. w/PHD  \
# 0      130.0              800.0             1500.0          76.0
# 1      155.0              650.0             2304.0          67.0
# 2       34.0              500.0             1162.0          39.0
# 3      114.0              580.0             1260.0          48.0
# 4      155.0              500.0              850.0          53.0
#
#    stud./fac. ratio  Graduation rate
# 0              11.9             15.0
# 1              10.0              NaN
# 2               9.5             39.0
# 3              13.7              NaN
# 4              14.3             40.0

# %%
df.info()
# outputs information about different columns, like the type, the non-null count, etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   College Name              1302 non-null   object
#  1   State                     1302 non-null   object
#  2   Public (1)/ Private (2)   1302 non-null   int64
#  3   # appli. rec'd            1292 non-null   float64
#  4   # appl. accepted          1291 non-null   float64
#  5   # new stud. enrolled      1297 non-null   float64
#  6   % new stud. from top 10%  1067 non-null   float64
#  7   % new stud. from top 25%  1100 non-null   float64
#  8   # FT undergrad            1299 non-null   float64
#  9   # PT undergrad            1270 non-null   float64
#  10  in-state tuition          1272 non-null   float64
#  11  out-of-state tuition      1282 non-null   float64
#  12  room                      981 non-null    float64
#  13  board                     804 non-null    float64
#  14  add. fees                 1028 non-null   float64
#  15  estim. book costs         1254 non-null   float64
#  16  estim. personal $         1121 non-null   float64
#  17  % fac. w/PHD              1270 non-null   float64
#  18  stud./fac. ratio          1300 non-null   float64
#  19  Graduation rate           1204 non-null   float64
# dtypes: float64(17), int64(1), object(2)
# memory usage: 203.6+ KB

# %%
df.describe()
# outputs summary statistics (mean, median, 25 and 75 quantiles, etc.) about the numerical columns
# Out:
#        Public (1)/ Private (2)  # appli. rec'd  # appl. accepted  \
# count              1302.000000     1292.000000       1291.000000
# mean                  1.639017     2752.097523       1870.683191
# std                   0.480470     3541.974712       2250.866400
# min                   1.000000       35.000000         35.000000
# 25%                   1.000000      695.750000        554.500000
# 50%                   2.000000     1470.000000       1095.000000
# 75%                   2.000000     3314.250000       2303.000000
# max                   2.000000    48094.000000      26330.000000
#
#        # new stud. enrolled  % new stud. from top 10%  \
# count           1297.000000               1067.000000
# mean             778.880493                 25.671978
# std              884.578274                 18.312618
# min               18.000000                  1.000000
# 25%              236.000000                 13.000000
# 50%              447.000000                 21.000000
# 75%              984.000000                 32.000000
# max             7425.000000                 98.000000
#
#        % new stud. from top 25%  # FT undergrad  # PT undergrad  \
# count               1100.000000     1299.000000     1270.000000
# mean                  52.350000     3692.665127     1081.526772
# std                   20.881316     4544.847897     1672.202912
# min                    6.000000       59.000000        1.000000
# 25%                   36.750000      966.000000      131.250000
# 50%                   50.000000     1812.000000      472.000000
# 75%                   66.000000     4539.500000     1313.000000
# max                  100.000000    31643.000000    21836.000000
#
#        in-state tuition  out-of-state tuition         room        board  \
# count       1272.000000           1282.000000   981.000000   804.000000
# mean        7897.274371           9276.905616  2514.681957  2060.983831
# std         5348.162626           4170.770851  1150.836848   661.742099
# min          480.000000           1044.000000   500.000000   531.000000
# 25%         2580.000000           6111.000000  1710.000000  1619.250000
# 50%         8050.000000           8670.000000  2200.000000  1980.000000
# 75%        11600.000000          11659.000000  3040.000000  2401.500000
# max        25750.000000          25750.000000  7400.000000  6250.000000
#
#          add. fees  estim. book costs  estim. personal $  % fac. w/PHD  \
# count  1028.000000        1254.000000        1121.000000   1270.000000
# mean    392.012646         549.972887        1389.291704     68.645669
# std     469.379234         167.355386         714.247857     17.825627
# min       9.000000          90.000000          75.000000      8.000000
# 25%     130.000000         480.000000         900.000000     57.000000
# 50%     264.500000         502.000000        1250.000000     71.000000
# 75%     480.000000         600.000000        1794.000000     82.000000
# max    4374.000000        2340.000000        6900.000000    105.000000
#
#        stud./fac. ratio  Graduation rate
# count       1300.000000      1204.000000
# mean          14.858769        60.405316
# std            5.186399        18.889058
# min            2.300000         8.000000
# 25%           11.800000        47.000000
# 50%           14.300000        60.000000
# 75%           17.600000        74.000000
# max           91.800000       118.000000

# %%
df.describe(include='O')
# outputs summary statistics (count, unique, top, etc.) of non-numerical columns.
# Out:
#              College Name State
# count                1302  1302
# unique               1274    51
# top     Concordia College    NY
# freq                    4   101

# %%
df.isna().sum()
# number of null values in each column
# Out:
# College Name                  0
# State                         0
# Public (1)/ Private (2)       0
# # appli. rec'd               10
# # appl. accepted             11
# # new stud. enrolled          5
# % new stud. from top 10%    235
# % new stud. from top 25%    202
# # FT undergrad                3
# # PT undergrad               32
# in-state tuition             30
# out-of-state tuition         20
# room                        321
# board                       498
# add. fees                   274
# estim. book costs            48
# estim. personal $           181
# % fac. w/PHD                 32
# stud./fac. ratio              2
# Graduation rate              98
# dtype: int64

# %%
missingno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# > we can see in the above visualization that many columns are missing many values, namely, the % of new students from top 10 and 25%, the room cost, the board cost, the additional fees, and the estimated personal cost. We also see missing values in the graduation rate.
# >
# > The missing values in thenew students from top 10% and 25% can be filled with 0s, as we will assume that no new students are from the top 10 or 25%, which could be the result of missing values.
# >
# > For the graduation rate missing values, we will need to drop those rows, as this is going to be our target variable, so we cannot impute the missing values, as this would be synthetic data, which should not be used for a target variable.
# >
# > For the other missing values, we will visualize them to see how to best fill in the missing values, then determine if the columns are worth keeping.

# %%
df.shape
# shape of the data (rows, columns)
# Out:
# (1302, 20)

# %% [markdown]
# ## Column Renaming

# %% [markdown]
# I will do some column renaming to make usage easier.

# %%
df.columns
# Out:
# Index(['College Name', 'State', 'Public (1)/ Private (2)', '# appli. rec'd',
#        '# appl. accepted', '# new stud. enrolled', '% new stud. from top 10%',
#        '% new stud. from top 25%', '# FT undergrad', '# PT undergrad',
#        'in-state tuition', 'out-of-state tuition', 'room', 'board',
#        'add. fees', 'estim. book costs', 'estim. personal $', '% fac. w/PHD',
#        'stud./fac. ratio', 'Graduation rate'],
#       dtype='object')

# %%
df.rename(columns={
    '# appli. rec\'d': 'applications_recieved', 
    '# appl. accepted': 'applications_accepted', 
    '# new stud. enrolled': 'new_student_enrolled', 
    '% new stud. from top 10%': 'new_student_top_10',
    '% new stud. from top 25%': 'new_student_top_25', 
    '# FT undergrad': 'full_time_undergrad', 
    '# PT undergrad': 'part_time_undergrad',
    'stud./fac. ratio': 'student_faculty_ratio'
}, inplace=True)

# %%
df.head()
# Out:
#                         College Name State  Public (1)/ Private (2)  \
# 0          Alaska Pacific University    AK                        2
# 1  University of Alaska at Fairbanks    AK                        1
# 2     University of Alaska Southeast    AK                        1
# 3  University of Alaska at Anchorage    AK                        1
# 4        Alabama Agri. & Mech. Univ.    AL                        1
#
#    applications_recieved  applications_accepted  new_student_enrolled  \
# 0                  193.0                  146.0                  55.0
# 1                 1852.0                 1427.0                 928.0
# 2                  146.0                  117.0                  89.0
# 3                 2065.0                 1598.0                1162.0
# 4                 2817.0                 1920.0                 984.0
#
#    new_student_top_10  new_student_top_25  full_time_undergrad  \
# 0                16.0                44.0                249.0
# 1                 NaN                 NaN               3885.0
# 2                 4.0                24.0                492.0
# 3                 NaN                 NaN               6209.0
# 4                 NaN                 NaN               3958.0
#
#    part_time_undergrad  in-state tuition  out-of-state tuition    room  \
# 0                869.0            7560.0                7560.0  1620.0
# 1               4519.0            1742.0                5226.0  1800.0
# 2               1849.0            1742.0                5226.0  2514.0
# 3              10537.0            1742.0                5226.0  2600.0
# 4                305.0            1700.0                3400.0  1108.0
#
#     board  add. fees  estim. book costs  estim. personal $  % fac. w/PHD  \
# 0  2500.0      130.0              800.0             1500.0          76.0
# 1  1790.0      155.0              650.0             2304.0          67.0
# 2  2250.0       34.0              500.0             1162.0          39.0
# 3  2520.0      114.0              580.0             1260.0          48.0
# 4  1442.0      155.0              500.0              850.0          53.0
#
#    student_faculty_ratio  Graduation rate
# 0                   11.9             15.0
# 1                   10.0              NaN
# 2                    9.5             39.0
# 3                   13.7              NaN
# 4                   14.3             40.0

# %%
df['school_type'] = df['Public (1)/ Private (2)'].map({1: 'Public', 2: 'Private'})

# %%
df.head()
# Out:
#                         College Name State  Public (1)/ Private (2)  \
# 0          Alaska Pacific University    AK                        2
# 1  University of Alaska at Fairbanks    AK                        1
# 2     University of Alaska Southeast    AK                        1
# 3  University of Alaska at Anchorage    AK                        1
# 4        Alabama Agri. & Mech. Univ.    AL                        1
#
#    applications_recieved  applications_accepted  new_student_enrolled  \
# 0                  193.0                  146.0                  55.0
# 1                 1852.0                 1427.0                 928.0
# 2                  146.0                  117.0                  89.0
# 3                 2065.0                 1598.0                1162.0
# 4                 2817.0                 1920.0                 984.0
#
#    new_student_top_10  new_student_top_25  full_time_undergrad  \
# 0                16.0                44.0                249.0
# 1                 NaN                 NaN               3885.0
# 2                 4.0                24.0                492.0
# 3                 NaN                 NaN               6209.0
# 4                 NaN                 NaN               3958.0
#
#    part_time_undergrad  ...  out-of-state tuition    room   board  add. fees  \
# 0                869.0  ...                7560.0  1620.0  2500.0      130.0
# 1               4519.0  ...                5226.0  1800.0  1790.0      155.0
# 2               1849.0  ...                5226.0  2514.0  2250.0       34.0
# 3              10537.0  ...                5226.0  2600.0  2520.0      114.0
# 4                305.0  ...                3400.0  1108.0  1442.0      155.0
#
#    estim. book costs  estim. personal $  % fac. w/PHD  student_faculty_ratio  \
# 0              800.0             1500.0          76.0                   11.9
# 1              650.0             2304.0          67.0                   10.0
# 2              500.0             1162.0          39.0                    9.5
# 3              580.0             1260.0          48.0                   13.7
# 4              500.0              850.0          53.0                   14.3
#
#    Graduation rate  school_type
# 0             15.0      Private
# 1              NaN       Public
# 2             39.0       Public
# 3              NaN       Public
# 4             40.0       Public
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Outlier Cleaning

# %% [markdown]
# > For the most part, outliers will remain in the dataset, as having a high tuition, high acceptance rate, etc. are likely real data. removing outliers should not be done on real data unless it interferes with the analysis or modeling I am trying to perform. In this case, the model should understand outliers mean large schools, which shouldn't affect my modeling nor my analysis, so they will remain. When imputing values however, I will do so without the outliers to get better imputations.
# >
# > One outlier will be removed, and that is where the gradution rate is 118%. This is clearly an error, and so should be removed. I will also in the same step, remove columns with missing values for graduation rate, as they should be removed.

# %%
df.shape
# Out:
# (1302, 21)

# %%
df = df[df['Graduation rate'] <= 100.0]

# %%
df.shape
# Out:
# (1203, 21)

# %%
df['Graduation rate'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Visualizations

# %% [markdown]
# In this section, I will visualize some of the main data points to find patterns and trends in the data, as well as determine how the value should be imputed.

# %% [markdown]
# ### Helper functions

# %%
def plot_hist_box(data, column):
    """
    Creator: Daniel Gallo
    Inputs: 
        Data - The dataframe from which to perform the logic in
        Column: the column in the dataframe to focus on
    Outputs:
        Outputs a figure with a histogram of the specified column on top, and a boxplot of the same data on the bottom. 
        This histogram also shows the median and mean of the data. 
    """
    fig, axes = plt.subplots(2, 1, figsize=(7,7))
    sns.histplot(data=data, x=column, ax=axes[0], bins=50, kde=True)
    mean = data[column].mean()
    axes[0].axvline(x=mean, color='green', label='Mean')
    sns.boxplot(data=data, x=column, ax=axes[1])
    median = data[column].median()
    axes[0].axvline(x=median, color='red', label='Median')
    plt.tight_layout()
    axes[0].legend()

# %%
def get_mean_without_outliers(series):
    """
    Creator: Daniel Gallo
    Inputs: 
        Series
    Outputs:
        Returns the mean of a numeric series without the outliers. 
    """
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)

    x = series[(series >= lower_bound) & (series <= upper_bound)]
    return x.mean()

# %%
def get_median_without_outliers(series):
    """
    Creator: Daniel Gallo
    Inputs: 
        Series
    Outputs:
        Returns the median of a numeric series without the outliers. 
    """
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1

    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)

    x = series[(series >= lower_bound) & (series <= upper_bound)]
    return x.median()

# %% [markdown]
# ### Tuition Costs

# %%
plot_hist_box(df, 'in-state tuition')
plt.savefig("./images/in-state-unclean.png")

# %%
plot_hist_box(df, 'out-of-state tuition')
plt.savefig("./images/out-of-state-unclean.png")

# %% [markdown]
# > For the in-state tuition, we will impute with the median cost, as it is more bi-modal than normal distribution. However, for the out of state tuition, we will inpute with the mean, as this follows more of a normal distribution.
# >
# > Also, as states have different number of colleges, and cost can vary by state, we will group by state to impute.

# %%
df['in-state tuition'] = df['in-state tuition'].fillna(df.groupby('State')['in-state tuition'].transform('mean'))
df['out-of-state tuition'] = df['out-of-state tuition'].fillna(df.groupby('State')['out-of-state tuition'].transform('median'))

# %%
plot_hist_box(df, 'in-state tuition')
plt.savefig('./images/in-state-clean.png')

# %% [markdown]
# > While only minor differeces are apparent, the overall mean in-state tuition seems to have risen.

# %%
plot_hist_box(df, 'out-of-state tuition')
plt.savefig('./images/out-of-state-clean.png')

# %% [markdown]
# > Again, only minor changes are apparent, but one noticible differece is that there were at 5 shown outliers prior, but now, after imputing, there are 6 shown outliers. This indicates that the q1 or q3 has changed, so the boundry has shrunk, causing more outliers.

# %% [markdown]
# ## Room and Board

# %%
plot_hist_box(df, 'room')
plt.savefig('./images/room-unclean.png')

# %% [markdown]
# > We can see this is very clearly right skewed, so we should use the median to impute values.

# %%
df['room'] = df['room'].fillna(get_median_without_outliers(df['room']))

# %%
plot_hist_box(df, 'room')
plt.savefig('./images/room-clean.png')

# %% [markdown]
# > We can see now that there is a spike around the median. As there were many missing values for `room`, and we imputed them with all the same value, this is to be expected.

# %%
plot_hist_box(df, 'board')
plt.savefig('./images/board-unclean.png')

# %% [markdown]
# > Here, we can see the price of board is pretty close to normally distributed, and probably would be if not for the outliers higher than 4000. So, for this one, we will impute with the mean.

# %%
df['board'] = df['board'].fillna(get_mean_without_outliers(df['board']))

# %%
plot_hist_box(df, 'board')
plt.savefig('./images/board-clean.png')

# %% [markdown]
# > The same as before with room, there is a spike around the mean (and median in this case) as we imputed the missing values with the same value, so this is expected.

# %% [markdown]
# These may look odd from a visualization perspective, but imputing these valeus is crucial, so as to not remove rows that may be needed.

# %% [markdown]
# ## Top 10% and 25%

# %% [markdown]
# > These columns should be filled with 0s, as stated previosuly.

# %%
df['new_student_top_10'] = df['new_student_top_10'].fillna(0)
df['new_student_top_25'] = df['new_student_top_25'].fillna(0)

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Here is where I will select the features I believe will contribute most to Graduation Rate

# %%
df.columns
# Out:
# Index(['College Name', 'State', 'Public (1)/ Private (2)',
#        'applications_recieved', 'applications_accepted',
#        'new_student_enrolled', 'new_student_top_10', 'new_student_top_25',
#        'full_time_undergrad', 'part_time_undergrad', 'in-state tuition',
#        'out-of-state tuition', 'room', 'board', 'add. fees',
#        'estim. book costs', 'estim. personal $', '% fac. w/PHD',
#        'student_faculty_ratio', 'Graduation rate', 'school_type'],
#       dtype='object')

# %% [markdown]
# I do not believe that cost outside of tuition is a determining factor for graduation rate, so we can ignore columns relating to cost outside of tuition, room ,board, etc.

# %% [markdown]
# College state and name also would not be a determining factor, as that's based on the location, not the students attending, so they can be ignored as well.

# %% [markdown]
# I also do not believe the number of full time or part time students would affect graduation rate either, as this may tell us *when* they graduated, not *if* they graduated.

# %% [markdown]
# The number of applications received and accepted will likely not tell us much about the graduation rate, as this is how many students they get.

# %% [markdown]
# Tutition (in-state and out-of-state), new students from top 10 and 25, faculty with phd, student_faculty_ratio and school type I believe will all be important factors.

# %% [markdown]
# The tuition is important, as a higher costing school may have more rigorous programs, which is a major factor in graduating classes.

# %% [markdown]
# Students from the top 10 and top 25 is also a factor, as this tells how many well-performing students are attending, which could bring graduation rates up.
#
# The number of new students is also important in the same way, since the top 10 and 25 are percents of the new students enrolled, so it should also be included.

# %% [markdown]
# Student faculty ratio and faculty with phd would affect how much personalized help students can get and how knowledgeable the faculty is, both of which would help graduation rates.

# %% [markdown]
# Private vs Public schools is also important, as they may have different criteria when it comes to who graduates and who does not.

# %%
accepted_columns = ['in-state tuition', 'out-of-state tuition', 'new_student_top_10', 'new_student_top_25', 'new_student_enrolled', '% fac. w/PHD', 'student_faculty_ratio', 'school_type', 'Graduation rate']

# %%
new_df = df[accepted_columns]

# %%
new_df.isna().sum()
# Out:
# in-state tuition          0
# out-of-state tuition      0
# new_student_top_10        0
# new_student_top_25        0
# new_student_enrolled      2
# % fac. w/PHD             27
# student_faculty_ratio     0
# school_type               0
# Graduation rate           0
# dtype: int64

# %%
new_df = new_df.dropna()

# %%
new_df.isna().sum()
# Out:
# in-state tuition         0
# out-of-state tuition     0
# new_student_top_10       0
# new_student_top_25       0
# new_student_enrolled     0
# % fac. w/PHD             0
# student_faculty_ratio    0
# school_type              0
# Graduation rate          0
# dtype: int64

# %%
new_df.shape
# Out:
# (1174, 9)

# %%
new_df.to_csv('./data/cleaned_universities.csv')
