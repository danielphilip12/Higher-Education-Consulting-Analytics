# %%
import pandas as pd
import pickle

# %%
df = pd.read_csv('./data/cleaned_universities.csv')

# %%
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
testing = df.sample(5)

# %%
testing
# Out:
#      in-state tuition  out-of-state tuition  new_student_top_10  \
# 359            4400.0                4400.0                 0.0
# 891            2370.0                6694.0                15.0
# 957            7440.0                7440.0                23.0
# 683            9990.0                9990.0                30.0
# 694            7470.0                7470.0                14.0
#
#      new_student_top_25  new_student_enrolled    room        board  \
# 359                 0.0                 171.0  2160.0  2036.312162
# 891                50.0                1030.0  2537.0  2600.000000
# 957                52.0                 721.0  2160.0  2036.312162
# 683                70.0                 302.0  1850.0  1700.000000
# 694                48.0                 238.0  4600.0  2036.312162
#
#      % fac. w/PHD  student_faculty_ratio school_type  full_time_undergrad  \
# 359          72.0                   16.1     Private                674.0
# 891          74.0                   15.7      Public               4882.0
# 957          70.0                   18.1     Private               2885.0
# 683          85.0                   15.0     Private               1210.0
# 694          74.0                   15.3     Private               1170.0
#
#      part_time_undergrad  estim. book costs  estim. personal $  \
# 359                472.0              534.0        1321.797862
# 891               2706.0              500.0        1321.797862
# 957                537.0              450.0        2200.000000
# 683                 26.0              500.0        1500.000000
# 694                429.0              250.0        1400.000000
#
#      Graduation rate  school_type_codes
# 359             73.0                  0
# 891             47.0                  1
# 957             60.0                  0
# 683             67.0                  0
# 694             88.0                  0

# %%
testing['school_type'] = testing['school_type'].astype('category')
testing['school_type_codes'] = testing['school_type'].cat.codes

# %%
testing.drop(columns=['Graduation rate', 'school_type'], inplace=True)

# %%
model.predict(testing)
# Out:
# array([46.24, 48.38, 60.33, 67.43, 61.21])

# %%
model.feature_names_in_
# Out:
# array(['in-state tuition', 'out-of-state tuition', 'new_student_top_10',
#        'new_student_top_25', 'new_student_enrolled', 'room', 'board',
#        '% fac. w/PHD', 'student_faculty_ratio', 'full_time_undergrad',
#        'part_time_undergrad', 'estim. book costs', 'estim. personal $',
#        'school_type_codes'], dtype=object)
